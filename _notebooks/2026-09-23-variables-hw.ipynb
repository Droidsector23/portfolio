# %% [markdown]
# ---
# layout: post
# title: UESL 3.1 Homework
# author: your-github-id
# permalink: /homework/3-1/
# ---

# %% [markdown]
# ## Popcorn

# %% [markdown]
# ## MCQ

# %%
print("1: B")
print("2: A")
print("3: C")
print("4: B")
# Out:
# 1: B
# 2: A
# 3: C
# 4: B

# %% [markdown]
# ## HW
