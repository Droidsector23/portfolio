# %% [markdown]
# ---
# layout: post
# title: UESL 3.2 Homework
# author: your-github-id
# permalink: /homework/3-2/
# ---

# %%
## Popcorn

# %%
## MCQ
print("1: B")
print("2: A")
print("3: C")
print("4: B")
# Out:
# 1: B

# %%
## Homework

# %%
## Tests

# %%
## Design Thinking
